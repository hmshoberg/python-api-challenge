# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 601

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"
    
# Define an empty list to fetch the weather data for each city

city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}q={city}&units=imperial&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve data
        weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = weather['coord']['lat']
        city_lng = weather['coord']['lon']
        city_max_temp = weather['main']['temp_max']
        city_humidity = weather['main']['humidity']
        city_clouds = weather['clouds']['all']
        city_wind = weather['wind']['speed']
        city_country = weather['sys']['country']
        city_date = weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except Exception as e:
        print(f"City {city} not found. Skipping... Error: {e}")
        pass
    
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | thompson
# Processing Record 2 of Set 1 | vila do maio
# Processing Record 3 of Set 1 | margaret river
# Processing Record 4 of Set 1 | strezhevoy
# Processing Record 5 of Set 1 | san antonio de pale
# Processing Record 6 of Set 1 | puerto natales
# Processing Record 7 of Set 1 | yinchuan
# Processing Record 8 of Set 1 | fale old settlement
# Processing Record 9 of Set 1 | college
# Processing Record 10 of Set 1 | belyy yar
# Processing Record 11 of Set 1 | whitehorse
# Processing Record 12 of Set 1 | peace river
# Processing Record 13 of Set 1 | sisimiut
# Processing Record 14 of Set 1 | hanceville
# Processing Record 15 of Set 1 | mount pearl
# Processing Record 16 of Set 1 | hazleton
# Processing Record 17 of Set 1 | callao
# Processing Record 18 of Set 1 | ulanhot
# Processing Record 19 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 20 of Set 1 | sao jose da coroa grande
# Processing Record 21 of Set 1 | luderitz
# Processing Record 22 of Set 1 | adamstown
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | the pas
# Processing Record 25 of Set 1 | khandyga
# Processing Record 26 of Set 1 | puerto gaitan
# Processing Record 27 of Set 1 | argo
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | waitangi
# Processing Record 30 of Set 1 | wailua homesteads
# Processing Record 31 of Set 1 | tafuna
# Processing Record 32 of Set 1 | vuktyl
# Processing Record 33 of Set 1 | port-vila
# Processing Record 34 of Set 1 | port-aux-francais
# Processing Record 35 of Set 1 | longgang
# Processing Record 36 of Set 1 | klyuchi
# Processing Record 37 of Set 1 | severo-yeniseyskiy
# Processing Record 38 of Set 1 | mirnyy
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | flying fish cove
# Processing Record 42 of Set 1 | ancud
# Processing Record 43 of Set 1 | blackmans bay
# Processing Record 44 of Set 1 | mount isa
# Processing Record 45 of Set 1 | west island
# Processing Record 46 of Set 1 | lewistown
# Processing Record 47 of Set 1 | coquimbo
# Processing Record 48 of Set 1 | bethel
# Processing Record 49 of Set 1 | nyurba
# Processing Record 50 of Set 1 | lihue
# Processing Record 0 of Set 2 | kiamba
# Processing Record 1 of Set 2 | morehead city
# Processing Record 2 of Set 2 | hammerfest
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | lodwar
# Processing Record 5 of Set 2 | saynshand
# Processing Record 6 of Set 2 | fuvahmulah
# City fuvahmulah not found. Skipping... Error: 'coord'
# Processing Record 7 of Set 2 | tottori
# Processing Record 8 of Set 2 | st. john's
# Processing Record 9 of Set 2 | vila franca do campo
# Processing Record 10 of Set 2 | quellon
# Processing Record 11 of Set 2 | iqaluit
# Processing Record 12 of Set 2 | trairi
# Processing Record 13 of Set 2 | pacific grove
# Processing Record 14 of Set 2 | grytviken
# Processing Record 15 of Set 2 | sinabang
# Processing Record 16 of Set 2 | ewo
# Processing Record 17 of Set 2 | kapa'a
# Processing Record 18 of Set 2 | polyarnyy
# Processing Record 19 of Set 2 | happy valley-goose bay
# Processing Record 20 of Set 2 | lovrin
# Processing Record 21 of Set 2 | puerto baquerizo moreno
# Processing Record 22 of Set 2 | porto novo
# Processing Record 23 of Set 2 | kristiansund
# Processing Record 24 of Set 2 | iskateley
# Processing Record 25 of Set 2 | san andros
# City san andros not found. Skipping... Error: 'coord'
# Processing Record 26 of Set 2 | tumaco
# Processing Record 27 of Set 2 | el calafate
# Processing Record 28 of Set 2 | badger
# Processing Record 29 of Set 2 | tolanaro
# Processing Record 30 of Set 2 | wanning
# Processing Record 31 of Set 2 | hwange
# Processing Record 32 of Set 2 | general levalle
# Processing Record 33 of Set 2 | oued rhiou
# Processing Record 34 of Set 2 | al ghayzah
# Processing Record 35 of Set 2 | el empalme
# Processing Record 36 of Set 2 | avarua
# Processing Record 37 of Set 2 | port elizabeth
# Processing Record 38 of Set 2 | valdez
# Processing Record 39 of Set 2 | uzgen
# Processing Record 40 of Set 2 | ak"yar
# City ak"yar not found. Skipping... Error: 'coord'
# Processing Record 41 of Set 2 | bilibino
# Processing Record 42 of Set 2 | puerto colombia
# Processing Record 43 of Set 2 | parabel'
# Processing Record 44 of Set 2 | lewisville
# Processing Record 45 of Set 2 | port lincoln
# Processing Record 46 of Set 2 | puerto ayora
# Processing Record 47 of Set 2 | howrah
# Processing Record 48 of Set 2 | genhe
# Processing Record 49 of Set 2 | udachny
# Processing Record 0 of Set 3 | invercargill
# Processing Record 1 of Set 3 | thunder bay
# Processing Record 2 of Set 3 | quepos
# Processing Record 3 of Set 3 | garissa
# Processing Record 4 of Set 3 | preobrazheniye
# Processing Record 5 of Set 3 | mega
# Processing Record 6 of Set 3 | la passe
# Processing Record 7 of Set 3 | saipan
# Processing Record 8 of Set 3 | lebu
# Processing Record 9 of Set 3 | seosan
# Processing Record 10 of Set 3 | naze
# Processing Record 11 of Set 3 | an nuhud
# Processing Record 12 of Set 3 | fiambala
# Processing Record 13 of Set 3 | cabedelo
# Processing Record 14 of Set 3 | ilulissat
# Processing Record 15 of Set 3 | touros
# Processing Record 16 of Set 3 | fortaleza
# Processing Record 17 of Set 3 | constantia
# Processing Record 18 of Set 3 | schleiz
# Processing Record 19 of Set 3 | olonkinbyen
# Processing Record 20 of Set 3 | fortuna
# Processing Record 21 of Set 3 | ghanzi
# Processing Record 22 of Set 3 | san fernando de apure
# Processing Record 23 of Set 3 | tosontsengel
# Processing Record 24 of Set 3 | aasiaat
# Processing Record 25 of Set 3 | east london
# Processing Record 26 of Set 3 | yung shue wan
# Processing Record 27 of Set 3 | altai
# Processing Record 28 of Set 3 | nuuk
# Processing Record 29 of Set 3 | hayma'
# City hayma' not found. Skipping... Error: 'coord'
# Processing Record 30 of Set 3 | yeraliyev
# Processing Record 31 of Set 3 | neunkirchen am brand
# Processing Record 32 of Set 3 | onega
# Processing Record 33 of Set 3 | east ballina
# Processing Record 34 of Set 3 | altamira
# Processing Record 35 of Set 3 | prince rupert
# Processing Record 36 of Set 3 | igarka
# Processing Record 37 of Set 3 | mukah
# City mukah not found. Skipping... Error: 'coord'
# Processing Record 38 of Set 3 | stanley
# Processing Record 39 of Set 3 | salgado
# Processing Record 40 of Set 3 | edinburgh of the seven seas
# Processing Record 41 of Set 3 | mount gambier
# Processing Record 42 of Set 3 | la ronge
# Processing Record 43 of Set 3 | susuman
# Processing Record 44 of Set 3 | tura
# Processing Record 45 of Set 3 | hawaiian paradise park
# Processing Record 46 of Set 3 | ust-nera
# Processing Record 47 of Set 3 | pointe aux piments
# Processing Record 48 of Set 3 | ribeira brava
# Processing Record 49 of Set 3 | arish
# Processing Record 0 of Set 4 | selfoss
# Processing Record 1 of Set 4 | malango
# Processing Record 2 of Set 4 | samut sakhon
# Processing Record 3 of Set 4 | northam
# Processing Record 4 of Set 4 | rechka-vydrino
# Processing Record 5 of Set 4 | tamanrasset
# Processing Record 6 of Set 4 | gubkinskiy
# Processing Record 7 of Set 4 | chonchi
# Processing Record 8 of Set 4 | thames
# Processing Record 9 of Set 4 | kuusamo
# Processing Record 10 of Set 4 | san patricio
# Processing Record 11 of Set 4 | qaqortoq
# Processing Record 12 of Set 4 | yanykurgan
# Processing Record 13 of Set 4 | barclayville
# Processing Record 14 of Set 4 | roma
# Processing Record 15 of Set 4 | taiohae
# City taiohae not found. Skipping... Error: 'coord'
# Processing Record 16 of Set 4 | saint-georges
# Processing Record 17 of Set 4 | atafu village
# Processing Record 18 of Set 4 | ribeira grande
# Processing Record 19 of Set 4 | utrik
# Processing Record 20 of Set 4 | chibougamau
# Processing Record 21 of Set 4 | minas de marcona
# Processing Record 22 of Set 4 | saint-louis
# Processing Record 23 of Set 4 | chui
# Processing Record 24 of Set 4 | hotan
# Processing Record 25 of Set 4 | tsiombe
# Processing Record 26 of Set 4 | korla
# Processing Record 27 of Set 4 | yellowknife
# Processing Record 28 of Set 4 | seryshevo
# Processing Record 29 of Set 4 | palmer
# Processing Record 30 of Set 4 | puerto madryn
# Processing Record 31 of Set 4 | podporozh'ye
# Processing Record 32 of Set 4 | shambu
# Processing Record 33 of Set 4 | kargasok
# Processing Record 34 of Set 4 | tambura
# Processing Record 35 of Set 4 | south venice
# Processing Record 36 of Set 4 | galveston
# Processing Record 37 of Set 4 | svetlyy
# Processing Record 38 of Set 4 | isafjordur
# Processing Record 39 of Set 4 | el dorado
# Processing Record 40 of Set 4 | berbera
# Processing Record 41 of Set 4 | merrimac
# Processing Record 42 of Set 4 | dapa
# Processing Record 43 of Set 4 | rabaul
# Processing Record 44 of Set 4 | ushtobe
# Processing Record 45 of Set 4 | necochea
# Processing Record 46 of Set 4 | karratha
# Processing Record 47 of Set 4 | zarghun shahr
# Processing Record 48 of Set 4 | rawdon
# Processing Record 49 of Set 4 | bikenibeu village
# Processing Record 0 of Set 5 | arraial do cabo
# Processing Record 1 of Set 5 | terralba
# Processing Record 2 of Set 5 | kuta
# Processing Record 3 of Set 5 | tionk essil
# Processing Record 4 of Set 5 | kailua-kona
# Processing Record 5 of Set 5 | bei'an
# Processing Record 6 of Set 5 | general pico
# Processing Record 7 of Set 5 | condoto
# Processing Record 8 of Set 5 | luganville
# Processing Record 9 of Set 5 | tazacorte
# Processing Record 10 of Set 5 | zadawa
# Processing Record 11 of Set 5 | kapuskasing
# Processing Record 12 of Set 5 | khovd
# Processing Record 13 of Set 5 | ushuaia
# Processing Record 14 of Set 5 | paracuru
# Processing Record 15 of Set 5 | westport
# Processing Record 16 of Set 5 | kuhdasht
# Processing Record 17 of Set 5 | vorgashor
# Processing Record 18 of Set 5 | antsiranana
# Processing Record 19 of Set 5 | gueltat zemmour
# City gueltat zemmour not found. Skipping... Error: 'coord'
# Processing Record 20 of Set 5 | sivas
# Processing Record 21 of Set 5 | codrington
# Processing Record 22 of Set 5 | qeshm
# Processing Record 23 of Set 5 | colonia menno
# Processing Record 24 of Set 5 | zhangye
# Processing Record 25 of Set 5 | shaowu
# Processing Record 26 of Set 5 | bredasdorp
# Processing Record 27 of Set 5 | juneau
# Processing Record 28 of Set 5 | norton
# Processing Record 29 of Set 5 | puerto leguizamo
# Processing Record 30 of Set 5 | medicine hat
# Processing Record 31 of Set 5 | keflavik
# Processing Record 32 of Set 5 | papatowai
# Processing Record 33 of Set 5 | puerto san carlos
# City puerto san carlos not found. Skipping... Error: 'coord'
# Processing Record 34 of Set 5 | dibba al-hisn
# Processing Record 35 of Set 5 | gebeit
# Processing Record 36 of Set 5 | sanctuary point
# Processing Record 37 of Set 5 | georgetown
# Processing Record 38 of Set 5 | dudinka
# Processing Record 39 of Set 5 | blonie
# Processing Record 40 of Set 5 | carauari
# Processing Record 41 of Set 5 | aykhal
# Processing Record 42 of Set 5 | beledweyne
# Processing Record 43 of Set 5 | tanumah
# Processing Record 44 of Set 5 | ahau
# City ahau not found. Skipping... Error: 'coord'
# Processing Record 45 of Set 5 | mirny
# Processing Record 46 of Set 5 | vilyuysk
# Processing Record 47 of Set 5 | belcista
# Processing Record 48 of Set 5 | grand baie
# Processing Record 49 of Set 5 | al kharijah
# Processing Record 0 of Set 6 | darwin
# Processing Record 1 of Set 6 | illizi
# Processing Record 2 of Set 6 | bardai
# Processing Record 3 of Set 6 | vadso
# Processing Record 4 of Set 6 | altamont
# Processing Record 5 of Set 6 | george town
# Processing Record 6 of Set 6 | tiksi
# Processing Record 7 of Set 6 | forster
# Processing Record 8 of Set 6 | liuhe
# Processing Record 9 of Set 6 | brisas de zicatela
# Processing Record 10 of Set 6 | alice springs
# Processing Record 11 of Set 6 | mgandu
# Processing Record 12 of Set 6 | cockburn town
# Processing Record 13 of Set 6 | mejit
# Processing Record 14 of Set 6 | zag
# Processing Record 15 of Set 6 | oranjemund
# Processing Record 16 of Set 6 | horta
# Processing Record 17 of Set 6 | queenstown
# Processing Record 18 of Set 6 | anadyr
# Processing Record 19 of Set 6 | bascov
# Processing Record 20 of Set 6 | abalak
# Processing Record 21 of Set 6 | santa elena de uairen
# Processing Record 22 of Set 6 | oistins
# Processing Record 23 of Set 6 | shouguang
# Processing Record 24 of Set 6 | caleta de carquin
# Processing Record 25 of Set 6 | tazovsky
# Processing Record 26 of Set 6 | amahai
# Processing Record 27 of Set 6 | mili
# Processing Record 28 of Set 6 | jining
# Processing Record 29 of Set 6 | longyearbyen
# Processing Record 30 of Set 6 | cabo san lucas
# Processing Record 31 of Set 6 | male
# Processing Record 32 of Set 6 | izyaslav
# Processing Record 33 of Set 6 | malmberget
# Processing Record 34 of Set 6 | swakopmund
# Processing Record 35 of Set 6 | del rio
# Processing Record 36 of Set 6 | nelson bay
# Processing Record 37 of Set 6 | uturoa
# Processing Record 38 of Set 6 | colonia
# Processing Record 39 of Set 6 | talnakh
# Processing Record 40 of Set 6 | fort bragg
# Processing Record 41 of Set 6 | rayachoti
# Processing Record 42 of Set 6 | altay
# Processing Record 43 of Set 6 | aioun
# Processing Record 44 of Set 6 | kirakira
# Processing Record 45 of Set 6 | oroqen zizhiqi
# Processing Record 46 of Set 6 | agadez
# Processing Record 47 of Set 6 | fannuj
# City fannuj not found. Skipping... Error: 'coord'
# Processing Record 48 of Set 6 | kuanda
# Processing Record 49 of Set 6 | kone
# Processing Record 0 of Set 7 | mhamid
# Processing Record 1 of Set 7 | at taj
# Processing Record 2 of Set 7 | gadag-betageri
# City gadag-betageri not found. Skipping... Error: 'coord'
# Processing Record 3 of Set 7 | curuzu cuatia
# Processing Record 4 of Set 7 | seclin
# Processing Record 5 of Set 7 | salalah
# Processing Record 6 of Set 7 | ulladulla
# Processing Record 7 of Set 7 | hamilton
# Processing Record 8 of Set 7 | anatoli
# Processing Record 9 of Set 7 | novodvinsk
# Processing Record 10 of Set 7 | kavaratti
# Processing Record 11 of Set 7 | marsh harbour
# Processing Record 12 of Set 7 | lompoc
# Processing Record 13 of Set 7 | ulcinj
# Processing Record 14 of Set 7 | revda
# Processing Record 15 of Set 7 | florencia
# Processing Record 16 of Set 7 | tapon
# Processing Record 17 of Set 7 | hobyo
# Processing Record 18 of Set 7 | suva
# Processing Record 19 of Set 7 | rockland
# Processing Record 20 of Set 7 | mendaha
# Processing Record 21 of Set 7 | port mathurin
# Processing Record 22 of Set 7 | afaahiti
# Processing Record 23 of Set 7 | chinchilla
# Processing Record 24 of Set 7 | kyongsong
# Processing Record 25 of Set 7 | broken hill
# Processing Record 26 of Set 7 | alaghsas
# Processing Record 27 of Set 7 | castelli
# Processing Record 28 of Set 7 | enewetak
# Processing Record 29 of Set 7 | nabire
# Processing Record 30 of Set 7 | 'ohonua
# City 'ohonua not found. Skipping... Error: 'coord'
# Processing Record 31 of Set 7 | talcahuano
# Processing Record 32 of Set 7 | prudentopolis
# Processing Record 33 of Set 7 | praia da vitoria
# Processing Record 34 of Set 7 | vernon
# Processing Record 35 of Set 7 | tofol
# Processing Record 36 of Set 7 | katabu
# Processing Record 37 of Set 7 | cargados carajos
# City cargados carajos not found. Skipping... Error: 'coord'
# Processing Record 38 of Set 7 | valparaiso
# Processing Record 39 of Set 7 | manta
# Processing Record 40 of Set 7 | enchanted hills
# Processing Record 41 of Set 7 | myshkin
# Processing Record 42 of Set 7 | cable beach
# City cable beach not found. Skipping... Error: 'coord'
# Processing Record 43 of Set 7 | goure
# Processing Record 44 of Set 7 | leer
# Processing Record 45 of Set 7 | nishinoomote
# Processing Record 46 of Set 7 | inhuma
# Processing Record 47 of Set 7 | ha'il
# Processing Record 48 of Set 7 | mawu
# Processing Record 49 of Set 7 | portland
# Processing Record 0 of Set 8 | sidi merouane
# Processing Record 1 of Set 8 | port saint john's
# Processing Record 2 of Set 8 | kyzyl-suu
# Processing Record 3 of Set 8 | jayapura
# Processing Record 4 of Set 8 | haiku-pauwela
# Processing Record 5 of Set 8 | laranjeiras do sul
# Processing Record 6 of Set 8 | khenchela
# Processing Record 7 of Set 8 | kununurra
# Processing Record 8 of Set 8 | nova sintra
# Processing Record 9 of Set 8 | waslala
# Processing Record 10 of Set 8 | colares
# Processing Record 11 of Set 8 | banda aceh
# Processing Record 12 of Set 8 | darreh shahr
# City darreh shahr not found. Skipping... Error: 'coord'
# Processing Record 13 of Set 8 | phan thiet
# Processing Record 14 of Set 8 | okha
# Processing Record 15 of Set 8 | klaksvik
# Processing Record 16 of Set 8 | santana
# Processing Record 17 of Set 8 | irtyshsk
# Processing Record 18 of Set 8 | arno
# Processing Record 19 of Set 8 | sabang
# Processing Record 20 of Set 8 | nagqu
# Processing Record 21 of Set 8 | port glaud
# City port glaud not found. Skipping... Error: 'coord'
# Processing Record 22 of Set 8 | lazaro cardenas
# Processing Record 23 of Set 8 | mohr
# Processing Record 24 of Set 8 | suntar
# Processing Record 25 of Set 8 | arkhangel'sk
# Processing Record 26 of Set 8 | sefwi wiawso
# City sefwi wiawso not found. Skipping... Error: 'coord'
# Processing Record 27 of Set 8 | baruun-urt
# Processing Record 28 of Set 8 | chust
# Processing Record 29 of Set 8 | tranovaho
# City tranovaho not found. Skipping... Error: 'coord'
# Processing Record 30 of Set 8 | al miqdadiyah
# Processing Record 31 of Set 8 | dryden
# Processing Record 32 of Set 8 | walvis bay
# Processing Record 33 of Set 8 | elliot lake
# Processing Record 34 of Set 8 | taybad
# Processing Record 35 of Set 8 | nyandoma
# Processing Record 36 of Set 8 | bejubang dua
# City bejubang dua not found. Skipping... Error: 'coord'
# Processing Record 37 of Set 8 | sitka
# Processing Record 38 of Set 8 | lilongwe
# Processing Record 39 of Set 8 | ghardaia
# Processing Record 40 of Set 8 | mwinilunga
# Processing Record 41 of Set 8 | gizo
# Processing Record 42 of Set 8 | pariaman
# Processing Record 43 of Set 8 | puerto aysen
# Processing Record 44 of Set 8 | raja
# Processing Record 45 of Set 8 | tadmur
# Processing Record 46 of Set 8 | ulan bator
# Processing Record 47 of Set 8 | sao jose da tapera
# Processing Record 48 of Set 8 | qingyuan
# Processing Record 49 of Set 8 | umm kaddadah
# Processing Record 0 of Set 9 | bangui
# Processing Record 1 of Set 9 | nadi
# Processing Record 2 of Set 9 | piacabucu
# Processing Record 3 of Set 9 | chifeng
# Processing Record 4 of Set 9 | decorah
# Processing Record 5 of Set 9 | bonthe
# Processing Record 6 of Set 9 | afif
# Processing Record 7 of Set 9 | malvan
# Processing Record 8 of Set 9 | shimokizukuri
# Processing Record 9 of Set 9 | kuqa
# Processing Record 10 of Set 9 | vilyuchinsk
# Processing Record 11 of Set 9 | papao
# Processing Record 12 of Set 9 | alliston
# Processing Record 13 of Set 9 | beira
# Processing Record 14 of Set 9 | gamba
# Processing Record 15 of Set 9 | newman
# Processing Record 16 of Set 9 | uyuni
# Processing Record 17 of Set 9 | angaur state
# Processing Record 18 of Set 9 | pont rouge
# Processing Record 19 of Set 9 | kusadasi
# Processing Record 20 of Set 9 | cill airne
# Processing Record 21 of Set 9 | lethem
# Processing Record 22 of Set 9 | la toma
# Processing Record 23 of Set 9 | zalingei
# Processing Record 24 of Set 9 | kizel
# Processing Record 25 of Set 9 | yoko
# Processing Record 26 of Set 9 | miri
# Processing Record 27 of Set 9 | vodnyy
# Processing Record 28 of Set 9 | mankivka
# Processing Record 29 of Set 9 | kardla
# Processing Record 30 of Set 9 | yerofey pavlovich
# Processing Record 31 of Set 9 | chengdu
# Processing Record 32 of Set 9 | partenit
# Processing Record 33 of Set 9 | strelka
# Processing Record 34 of Set 9 | fada
# Processing Record 35 of Set 9 | vom
# Processing Record 36 of Set 9 | remire-montjoly
# Processing Record 37 of Set 9 | murudeshwara
# Processing Record 38 of Set 9 | isangel
# Processing Record 39 of Set 9 | heroica matamoros
# Processing Record 40 of Set 9 | alamosa
# Processing Record 41 of Set 9 | barra de santo antonio
# Processing Record 42 of Set 9 | tayu
# Processing Record 43 of Set 9 | powell river
# Processing Record 44 of Set 9 | pisco
# Processing Record 45 of Set 9 | stuarts draft
# Processing Record 46 of Set 9 | namibe
# Processing Record 47 of Set 9 | hafar al-batin
# Processing Record 48 of Set 9 | islamorada
# City islamorada not found. Skipping... Error: HTTPSConnectionPool(host='api.openweathermap.org', port=443): Max retries exceeded with url: /data/2.5/weather?q=islamorada&units=imperial&appid=6601e0bcf2f71983fe69c43b9af926ee (Caused by SSLError(SSLEOFError(8, '[SSL: UNEXPECTED_EOF_WHILE_READING] EOF occurred in violation of protocol (_ssl.c:1007)')))
# Processing Record 49 of Set 9 | gadzhiyevo
# Processing Record 0 of Set 10 | ostroleka
# Processing Record 1 of Set 10 | piti village
# Processing Record 2 of Set 10 | new norfolk
# Processing Record 3 of Set 10 | christchurch
# Processing Record 4 of Set 10 | nova vicosa
# Processing Record 5 of Set 10 | devarkonda
# Processing Record 6 of Set 10 | vila velha
# Processing Record 7 of Set 10 | protaras
# Processing Record 8 of Set 10 | valenca do piaui
# Processing Record 9 of Set 10 | pirapora do bom jesus
# Processing Record 10 of Set 10 | jilib
# Processing Record 11 of Set 10 | istgah-e rah ahan-e garmsar
# Processing Record 12 of Set 10 | yeppoon
# Processing Record 13 of Set 10 | hadibu
# Processing Record 14 of Set 10 | charlottetown
# Processing Record 15 of Set 10 | chinnachowk
# Processing Record 16 of Set 10 | pasni
# Processing Record 17 of Set 10 | island harbour
# Processing Record 18 of Set 10 | jingdezhen
# Processing Record 19 of Set 10 | pangody
# Processing Record 20 of Set 10 | alma
# Processing Record 21 of Set 10 | holyhead
# Processing Record 22 of Set 10 | tromso
# Processing Record 23 of Set 10 | ilhabela
# Processing Record 24 of Set 10 | shiyan
# Processing Record 25 of Set 10 | ghadamis
# Processing Record 26 of Set 10 | kourou
# Processing Record 27 of Set 10 | tsengel
# Processing Record 28 of Set 10 | nemuro
# Processing Record 29 of Set 10 | derzhavinsk
# Processing Record 30 of Set 10 | malinyi
# Processing Record 31 of Set 10 | egilsstadir
# Processing Record 32 of Set 10 | mana
# Processing Record 33 of Set 10 | ra-ngae
# Processing Record 34 of Set 10 | linden
# Processing Record 35 of Set 10 | jimma
# Processing Record 36 of Set 10 | hilo
# Processing Record 37 of Set 10 | hithadhoo
# Processing Record 38 of Set 10 | amasra
# Processing Record 39 of Set 10 | nejo
# Processing Record 40 of Set 10 | taltal
# Processing Record 41 of Set 10 | tadine
# Processing Record 42 of Set 10 | vylkove
# Processing Record 43 of Set 10 | lyangasovo
# Processing Record 44 of Set 10 | bilovods'k
# Processing Record 45 of Set 10 | chernyshevskiy
# Processing Record 46 of Set 10 | port alfred
# Processing Record 47 of Set 10 | padam
# City padam not found. Skipping... Error: 'coord'
# Processing Record 48 of Set 10 | gongchangling
# Processing Record 49 of Set 10 | weno
# Processing Record 0 of Set 11 | waingapu
# Processing Record 1 of Set 11 | novoagansk
# Processing Record 2 of Set 11 | devinuwara
# City devinuwara not found. Skipping... Error: 'coord'
# Processing Record 3 of Set 11 | urucui
# Processing Record 4 of Set 11 | timbuktu
# Processing Record 5 of Set 11 | constitucion
# Processing Record 6 of Set 11 | shalkar
# Processing Record 7 of Set 11 | ta`u
# Processing Record 8 of Set 11 | inhambane
# Processing Record 9 of Set 11 | naracoorte
# Processing Record 10 of Set 11 | jaguarari
# Processing Record 11 of Set 11 | san juan de miraflores
# Processing Record 12 of Set 11 | tyumentsevo
# Processing Record 13 of Set 11 | lincheng
# Processing Record 14 of Set 11 | eastham
# Processing Record 15 of Set 11 | puerto lleras
# Processing Record 16 of Set 11 | yeniseysk
# Processing Record 17 of Set 11 | mazatlan
# Processing Record 18 of Set 11 | sakaiminato
# Processing Record 19 of Set 11 | arochukwu
# Processing Record 20 of Set 11 | taoudenni
# Processing Record 21 of Set 11 | urengoy
# Processing Record 22 of Set 11 | changji
# Processing Record 23 of Set 11 | dakhla
# Processing Record 24 of Set 11 | bechar
# Processing Record 25 of Set 11 | aldan
# Processing Record 26 of Set 11 | amga
# Processing Record 27 of Set 11 | chegdomyn
# Processing Record 28 of Set 11 | kiruna
# Processing Record 29 of Set 11 | agapovka
# Processing Record 30 of Set 11 | chos malal
# Processing Record 31 of Set 11 | buala
# Processing Record 32 of Set 11 | le plateau
# Processing Record 33 of Set 11 | puerto princesa
# Processing Record 34 of Set 11 | sao joao da barra
# Processing Record 35 of Set 11 | port macquarie
# Processing Record 36 of Set 11 | chehalis
# Processing Record 37 of Set 11 | antonio enes
# Processing Record 38 of Set 11 | rongelap
# Processing Record 39 of Set 11 | maragogi
# Processing Record 40 of Set 11 | qarqaraly
# Processing Record 41 of Set 11 | hasaki
# Processing Record 42 of Set 11 | saint-valery-en-caux
# Processing Record 43 of Set 11 | aomori
# Processing Record 44 of Set 11 | filadelfia
# Processing Record 45 of Set 11 | yelizovo
# Processing Record 46 of Set 11 | plettenberg bay
# Processing Record 47 of Set 11 | sur
# Processing Record 48 of Set 11 | ghazni
# Processing Record 49 of Set 11 | watampone
# Processing Record 0 of Set 12 | palikir - national government center
# Processing Record 1 of Set 12 | bellary
# Processing Record 2 of Set 12 | jinjiang
# Processing Record 3 of Set 12 | tevriz
# Processing Record 4 of Set 12 | rio verde de mato grosso
# Processing Record 5 of Set 12 | paita
# Processing Record 6 of Set 12 | glace bay
# Processing Record 7 of Set 12 | beni mellal
# Processing Record 8 of Set 12 | santa isabel
# Processing Record 9 of Set 12 | zubova polyana
# Processing Record 10 of Set 12 | kisangani
# Processing Record 11 of Set 12 | chebba
# Processing Record 12 of Set 12 | canutama
# Processing Record 13 of Set 12 | ormara
# Processing Record 14 of Set 12 | sharypovo
# Processing Record 15 of Set 12 | tommot
# Processing Record 16 of Set 12 | bodo
# Processing Record 17 of Set 12 | pampa del indio
# Processing Record 18 of Set 12 | tres arroyos
# Processing Record 19 of Set 12 | bel ombre
# Processing Record 20 of Set 12 | quibala
# Processing Record 21 of Set 12 | ola
# Processing Record 22 of Set 12 | basco
# Processing Record 23 of Set 12 | lorengau
# Processing Record 24 of Set 12 | san angelo
# Processing Record 25 of Set 12 | anchorage
# Processing Record 26 of Set 12 | laguna
# Processing Record 27 of Set 12 | kencong
# Processing Record 28 of Set 12 | talara
# Processing Record 29 of Set 12 | namie
# Processing Record 30 of Set 12 | polur
# Processing Record 31 of Set 12 | mahina
# Processing Record 32 of Set 12 | bima
# Processing Record 33 of Set 12 | stornoway
# Processing Record 34 of Set 12 | mstsislaw
# Processing Record 35 of Set 12 | fort mcmurray
# Processing Record 36 of Set 12 | kazalinsk
# City kazalinsk not found. Skipping... Error: 'coord'
# Processing Record 37 of Set 12 | santo antonio do leverger
# Processing Record 38 of Set 12 | riverton
# Processing Record 39 of Set 12 | hachinohe
# Processing Record 40 of Set 12 | katsuura
# Processing Record 41 of Set 12 | richards bay
# Processing Record 42 of Set 12 | akureyri
# Processing Record 43 of Set 12 | uttar char fasson
# Processing Record 44 of Set 12 | scotts valley
# Processing Record 45 of Set 12 | kingston
# Processing Record 46 of Set 12 | zdolbuniv
# Processing Record 47 of Set 12 | ugoofaaru
# Processing Record 48 of Set 12 | sishilichengzi
# City sishilichengzi not found. Skipping... Error: 'coord'
# Processing Record 49 of Set 12 | parchim
# Processing Record 0 of Set 13 | khost
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          577
# Lat           577
# Lng           577
# Max Temp      577
# Humidity      577
# Cloudiness    577
# Wind Speed    577
# Country       577
# Date          577
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             thompson  55.7435  -97.8558     33.96        80          75
# 1         vila do maio  15.1333  -23.2167     79.59        68          24
# 2       margaret river -33.9500  115.0667     51.91        77          77
# 3           strezhevoy  60.7333   77.5889     31.96        98         100
# 4  san antonio de pale  -1.4014    5.6325     79.36        83         100
#
#    Wind Speed Country        Date
# 0        8.05      CA  1699731250
# 1       12.57      CV  1699731251
# 2       14.16      AU  1699731251
# 3        5.99      RU  1699731252
# 4       10.78      GQ  1699731253

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                   thompson  55.7435  -97.8558     33.96        80
# 1               vila do maio  15.1333  -23.2167     79.59        68
# 2             margaret river -33.9500  115.0667     51.91        77
# 3                 strezhevoy  60.7333   77.5889     31.96        98
# 4        san antonio de pale  -1.4014    5.6325     79.36        83
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                75        8.05      CA  1699731250
# 1                24       12.57      CV  1699731251
# 2                77       14.16      AU  1699731251
# 3               100        5.99      RU  1699731252
# 4               100       10.78      GQ  1699731253

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
Lat = city_data_df['Lat']
Max_Temp = city_data_df['Max Temp']

# Incorporate the other graph properties
plt.scatter(Lat, Max_Temp, marker='o', facecolors='skyblue', edgecolors="black", alpha=0.75)
plt.title("City Max Latitude vs Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
Lat = city_data_df['Lat']
Humidity = city_data_df['Humidity']

# Incorporate the other graph properties
plt.scatter(Lat, Humidity, marker='o', facecolors='skyblue', edgecolors="black", alpha=0.75)
plt.title("City Latitude vs Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
Lat = city_data_df['Lat']
Cloudiness = city_data_df['Cloudiness']

# Incorporate the other graph properties
plt.scatter(Lat, Cloudiness, marker='o', facecolors='skyblue', edgecolors="black", alpha=0.75)
plt.title("City Latitude vs Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
Lat = city_data_df['Lat']
Wind_Speed = city_data_df['Wind Speed']

# Incorporate the other graph properties
plt.scatter(Lat, Wind_Speed, marker='o', facecolors='skyblue', edgecolors="black", alpha=0.75)
plt.title("City Latitude vs Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat']>0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0            thompson  55.7435  -97.8558     33.96        80          75
# 1        vila do maio  15.1333  -23.2167     79.59        68          24
# 3          strezhevoy  60.7333   77.5889     31.96        98         100
# 6            yinchuan  38.4681  106.2731     26.85        15           0
# 8             college  64.8569 -147.8028     15.75        79         100
#
#          Wind Speed Country        Date
# City_ID
# 0              8.05      CA  1699731250
# 1             12.57      CV  1699731251
# 3              5.99      RU  1699731252
# 6              3.06      CN  1699731255
# 8              4.61      US  1699731237

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat']<0]

# Display sample data
southern_hemi_df.head()
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 2             margaret river -33.9500  115.0667     51.91        77
# 4        san antonio de pale  -1.4014    5.6325     79.36        83
# 5             puerto natales -51.7236  -72.4875     48.65        40
# 7        fale old settlement  -9.3852 -171.2468     83.50        74
# 16                    callao -12.0667  -77.1500     73.69        60
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 2                77       14.16      AU  1699731251
# 4               100       10.78      GQ  1699731253
# 5                75       18.41      CL  1699731254
# 7                94        7.20      TK  1699731255
# 16               20       14.97      PE  1699731046

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Max Temp']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
regress_line = slope * x + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y,label = 'Data')
plt.plot(x, regress_line, color='red', label = 'Linear Regression Line')
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

plt.legend()
plt.show()

# %%
# Linear regression on Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Max Temp']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
regress_line = slope * x + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y,label = 'Data')
plt.plot(x, regress_line, color='red', label = 'Linear Regression Line')
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

plt.legend()
plt.show()
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Humidity']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
regress_line = slope * x + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y,label = 'Data')
plt.plot(x, regress_line, color='red', label = 'Linear Regression Line')
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.legend()
plt.show()

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Humidity']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
regress_line = slope * x + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y,label = 'Data')
plt.plot(x, regress_line, color='red', label = 'Linear Regression Line')
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Humidity')

plt.legend()
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Cloudiness']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
regress_line = slope * x + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y,label = 'Data')
plt.plot(x, regress_line, color='red', label = 'Linear Regression Line')
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.legend()
plt.show()

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Cloudiness']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
regress_line = slope * x + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y,label = 'Data')
plt.plot(x, regress_line, color='red', label = 'Linear Regression Line')
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

plt.legend()
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x = northern_hemi_df['Lat']
y = northern_hemi_df['Wind Speed']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
regress_line = slope * x + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y,label = 'Data')
plt.plot(x, regress_line, color='red', label = 'Linear Regression Line')
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.legend()
plt.show()

# %%
# Southern Hemisphere
x = southern_hemi_df['Lat']
y = southern_hemi_df['Wind Speed']
slope, intercept, r_value, p_value, std_err = linregress(x,y)
regress_line = slope * x + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x,y,label = 'Data')
plt.plot(x, regress_line, color='red', label = 'Linear Regression Line')
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")

plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

plt.legend()
plt.show()

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
